# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import seaborn as sns

import pandas as pd
df = pd.read_csv("Credit.csv")
df = df.iloc[:,1:7]
df
# Out:
#       Income  Limit  Rating  Cards  Age  Education
# 0     14.891   3606     283      2   34         11
# 1    106.025   6645     483      3   82         15
# 2    104.593   7075     514      4   71         11
# 3    148.924   9504     681      3   36         11
# 4     55.882   4897     357      2   68         16
# ..       ...    ...     ...    ...  ...        ...
# 395   12.096   4100     307      3   32         13
# 396   13.364   3838     296      5   65         17
# 397   57.872   4171     321      5   67         12
# 398   37.728   2525     192      1   44         13
# 399   18.701   5524     415      5   64          7
#
# [400 rows x 6 columns]

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Income', title = "Limit with Income")
sns.lmplot( x = 'Limit', y='Income', data = df)

# %%
# Residual Income
r1 = sns.residplot('Limit', 'Income', data= df)
r1.set(xlabel = 'Limit', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
# slope and the intercept for Income
lin_reg = LinearRegression()
lin_reg.fit(df[['Income']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([2389.86940892]), array([[51.8750206]]))

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Rating', title = "Limit with Rating")
sns.lmplot( x = 'Limit', y='Rating', data = df)

# %%
# Residual Rating
r1 = sns.residplot('Limit', 'Rating', data= df)
r1.set(xlabel = 'Limit', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
# slope and the intercept for Rating
lin_reg = LinearRegression()
lin_reg.fit(df[['Rating']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([-542.92822999]), array([[14.87160712]]))

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Cards', title = "Limit with Cards")
sns.lmplot( x = 'Limit', y='Cards', data = df)

# %%
# Residual Cards
r1 = sns.residplot('Limit', 'Cards', data= df)
r1.set(xlabel = 'Limit', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
# slope and the intercept for Cards
lin_reg = LinearRegression()
lin_reg.fit(df[['Cards']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4684.66624682]), array([[17.22189457]]))

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Age', title = "Limit with Age")
sns.lmplot( x = 'Limit', y='Age', data = df)

# %%
# Residual Age
r1 = sns.residplot('Limit', 'Age', data= df)
r1.set(xlabel = 'Limit', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
# slope and the intercept for Age
lin_reg = LinearRegression()
lin_reg.fit(df[['Age']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([3984.09845403]), array([[13.49982568]]))

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Education', title = "Limit with Education")
sns.lmplot( x = 'Limit', y='Education', data = df)

# %%
# Residual Education
r1 = sns.residplot('Limit', 'Education', data= df)
r1.set(xlabel = 'Limit', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
# slope and the intercept for Education
lin_reg = LinearRegression()
lin_reg.fit(df[['Education']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4969.52714909]), array([[-17.39235309]]))
