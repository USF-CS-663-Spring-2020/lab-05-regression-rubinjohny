# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import seaborn as sns

import pandas as pd
df = pd.read_csv("Credit.csv")
df = df.iloc[:,1:7]
df
# Out:
#       Income  Limit  Rating  Cards  Age  Education
# 0     14.891   3606     283      2   34         11
# 1    106.025   6645     483      3   82         15
# 2    104.593   7075     514      4   71         11
# 3    148.924   9504     681      3   36         11
# 4     55.882   4897     357      2   68         16
# ..       ...    ...     ...    ...  ...        ...
# 395   12.096   4100     307      3   32         13
# 396   13.364   3838     296      5   65         17
# 397   57.872   4171     321      5   67         12
# 398   37.728   2525     192      1   44         13
# 399   18.701   5524     415      5   64          7
#
# [400 rows x 6 columns]

# %%
df.plot(kind='scatter', x = 'Income', y = 'Limit', title = "Limit with Income")
sns.lmplot( x = 'Income', y='Limit', data = df)

# %%
# Residual Income
r1 = sns.residplot('Income', 'Limit', data= df)
r1.set(xlabel = 'Income', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Income')]

# %%
# slope and the intercept for Income
# from the residual graph, since it is distributed evenly we can say that Income is a good predictor
lin_reg = LinearRegression()
lin_reg.fit(df[['Income']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([2389.86940892]), array([[51.8750206]]))

# %%
df.plot(kind='scatter', x = 'Rating', y = 'Limit', title = "Limit with Rating")
sns.lmplot( x = 'Rating', y='Limit', data = df)

# %%
# Residual Rating
r1 = sns.residplot('Rating', 'Limit', data= df)
r1.set(xlabel = 'Rating', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Rating')]

# %%
# slope and the intercept for Rating
# from the residual graph since its evenly distributed, we can say that its a good predictor
lin_reg = LinearRegression()
lin_reg.fit(df[['Rating']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([-542.92822999]), array([[14.87160712]]))

# %%
df.plot(kind='scatter', x = 'Cards', y = 'Limit', title = "Limit with Cards")
sns.lmplot( x = 'Cards', y='Limit', data = df)

# %%
# Residual Cards
# since the residual graph is not evenly spread out, we can say that Cards is not a good predictor
r1 = sns.residplot('Cards', 'Limit', data= df)
r1.set(xlabel = 'Cards', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Cards')]

# %%
# slope and the intercept for Cards
lin_reg = LinearRegression()
lin_reg.fit(df[['Cards']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4684.66624682]), array([[17.22189457]]))

# %%
df.plot(kind='scatter', x = 'Age', y = 'Limit', title = "Limit with Age")
sns.lmplot( x = 'Age', y='Limit', data = df)

# %%
# Residual Age
# from the residual graph since its evenly distributed, we can say that Age is a good predictor
r1 = sns.residplot('Age', 'Limit', data= df)
r1.set(xlabel = 'Age', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Age')]

# %%
# slope and the intercept for Age
lin_reg = LinearRegression()
lin_reg.fit(df[['Age']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([3984.09845403]), array([[13.49982568]]))

# %%
df.plot(kind='scatter', x = 'Education', y = 'Limit', title = "Limit with Education")
sns.lmplot( x = 'Education', y='Limit', data = df)

# %%
# Residual Education
r1 = sns.residplot('Education', 'Limit', data= df)
r1.set(xlabel = 'Education', ylabel = 'Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Education')]

# %%
# slope and the intercept for Education
# since the residual graph is not evenly distributed, we can say that Education is not a good predictor
lin_reg = LinearRegression()
lin_reg.fit(df[['Education']], df[['Limit']])
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4969.52714909]), array([[-17.39235309]]))
